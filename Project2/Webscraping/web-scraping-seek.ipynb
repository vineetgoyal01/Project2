# %%
#importing modules for web-scraping
import requests
from bs4 import BeautifulSoup as bs
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager 
import pandas as pd
import time
import math
from collections import ChainMap



#importing modules for the API key 
#requests are already imported 
import json

# Google API Key
from config import gkey

# %%
#open the Chrome Driver web browser in order to do web-scraping 
executable_path = {'executable_path':'/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
#Web Scraping 1- need to interact with the job-seeking website first of all


jobs_find_url ="https://www.seek.com.au/jobs/in-All-Australia?keywords=%22data%20%20analyst%22"
browser.visit(jobs_find_url)
jobs_html=browser.html

# %% [markdown]
# The first step is to get the web-page url from the seek jobs website where the job includes "data analyst". The job search for this page is limited to all of Australia

# %% [markdown]
# Next, the number of pages that the search included needed to be obtained so that we know how many pages to loop through. It was found that there were 22 listings per page, and thus the numebr of jobs was divided by 22. After this it was noticed that the job advertisements just duplicate. Thus a decision was made to round up the number of pages/22 and then delete duplicate entries later.

# %%
# Retrieve page with the requests module

#it was noticed that the seek page had 22 jobs listed per page. Thus in order to obtain the number of pages, first need to obtain the number of pages:
#Number of jobs listed at the top of the page, the following code obtains this:
job_soup=bs(jobs_html, 'html.parser')
job_number=job_soup.find('span', class_="_3FrNV7v _3PZrylH _2heRYaN").text

number=job_number.strip('jobs found')

number_1=float(number)
print(number_1)

number_pages=math.ceil(number_1/22)
print(number_pages)

time.sleep(2)
# Out:
# 220.0
# 10

# %% [markdown]
# The code in the excerpt below saves the job title, location and company for data analyst jobs throughout Australia into lists. This was done through using looping and webscraping.

# %%
#getting the browser html
text_list=[]
job_location=[]
job_title1=[]
job_company=[]
job_classification=[]
x=range(1,number_pages+1)
for n in x:
    seek_url=f"https://www.seek.com.au/jobs/in-All-Australia?keywords=%22data%20%20analyst%22&page={n}"
    browser.visit(seek_url)
    seek_html=browser.html  
    seek_soup=bs(seek_html, 'html.parser')
    all_text=seek_soup.find('div', class_='_3MPUOLE')
    job_title=all_text.find_all('span', class_='_3FrNV7v _2IOW3OW HfVIlOd _2heRYaN E6m4BZb')
    extra_class=all_text.find_all('span', class_="Eadjc1o")
    job_characteristics=all_text.find_all('span', class_="_3FrNV7v _3PZrylH E6m4BZb")

    #converting each of the elements to text 
    
    #modifying the job location element and tidying up this element
    for element in extra_class:
        element1=element.text
        if "location:" in element1:
            element2=element1.lstrip('location: ')
            job_location.append(element2) 
    
    job_title=all_text.find_all('span', class_='_3FrNV7v _2IOW3OW HfVIlOd _2heRYaN E6m4BZb') 
    
    #editing both the job title and job characterstics
    for item in job_title:
        job1=item.text
        job_title1.append(job1)
    
    for company in job_characteristics:
        company1=company.text
        if company1[:3]=='at ':
            company2=company1.lstrip('at ')
            job_company.append(company2) 
    
    for job_class in extra_class:
        classification1=job_class.text
        if "classification:" in classification1:
            classification2=classification1.lstrip('classification: ')
            job_classification.append(classification2) 
    
    time.sleep(3)

# %%
browser.quit()

# %% [markdown]
# The lists were then combined in a pandas dataframe

# %%
#zip two lists together 

Job_df = pd.DataFrame(
    {'Job Title': job_title1,
     'Job Location': job_location,
     'Job Company': job_company,
     'Job Industry': job_classification
    })

# %%
Job_df.head(20)
# Out:
#                              Job Title                     Job Location  \
# 0              Junior Insights Analyst                           Sydney
# 1   Graduate Data Analyst & Programmer                       Gold Coast
# 2                         Data Analyst  West Gippsland & Latrobe Valley
# 3                 Data Analyst/Manager                           Sydney
# 4                         Data Analyst                              ACT
# 5         Graduate Estate Data Analyst                        Melbourne
# 6                         Data Analyst                           Sydney
# 7       Customer Insights Data Analyst                         Brisbane
# 8       Master Data Analyst - Reynella                         Adelaide
# 9             Scientist (Data Analyst)  Southern Highlands & Tablelands
# 10            Scientist (Data Analyst)  Southern Highlands & Tablelands
# 11          Cloud Data Analyst (Azure)                        Melbourne
# 12                 Oracle Data Analyst                           Sydney
# 13                        Data Analyst                        Melbourne
# 14                        Data Analyst                        Melbourne
# 15                        Data Analyst  West Gippsland & Latrobe Valley
# 16                    EL1 Data Analyst                              ACT
# 17                        Data Analyst                           Sydney
# 18                        Data Analyst                           Sydney
# 19                        Data Analyst                           Sydney
#
#                                          Job Company  \
# 0                                   Oneflare Pty Ltd
# 1                                   Tebbutt Research
# 2                        Hays Information Technology
# 3                    Finite IT Recruitment Solutions
# 4                          Hudson - Project Services
# 5                                             Ventia
# 6                               Teachers Mutual Bank
# 7                                eraDigital Services
# 8                           Accolade Wines Australia
# 9   Department of Planning, Industry and Environment
# 10  Department of Planning, Industry and Environment
# 11                                          Ambition
# 12                         Perigon Group Pty Limited
# 13        Department of Justice and Community Safety
# 14        Department of Justice and Community Safety
# 15                       Hays Information Technology
# 16                                   SOS Recruitment
# 17                                 Transport for NSW
# 18                                 Transport for NSW
# 19                                            Naviro
#
#                               Job Industry
# 0                                    Sales
# 1               Marketing & Communications
# 2                     Government & Defence
# 3   Information & Communication Technology
# 4   Information & Communication Technology
# 5                             Construction
# 6   Information & Communication Technology
# 7               Marketing & Communications
# 8   Information & Communication Technology
# 9                     Government & Defence
# 10                    Science & Technology
# 11  Information & Communication Technology
# 12  Information & Communication Technology
# 13                    Government & Defence
# 14  Information & Communication Technology
# 15                    Government & Defence
# 16                    Government & Defence
# 17            Banking & Financial Services
# 18                    Government & Defence
# 19  Information & Communication Technology

# %% [markdown]
# Duplicates were then removed from the dataset

# %%
#removing duplicates if all three columns are the same: 

Job_df2=Job_df.drop_duplicates()

# %% [markdown]
# In order to use the Leaflet library, the longitude and latitude co-ordinates needed to be obtained for each job, This will be done using the Google Places API. First, a search string column was added to the dataframe. This Search Engins column will be used as a parameter in the Google Places API.

# %%
#setting up search to use in the API call 
Job_df2["Search Engine"] = Job_df2["Job Company"].astype(str) + " " + Job_df2["Job Location"].astype(str)
# Out:
# /Users/dhanyamaheswaran/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Job_df2.head()
# Out:
#                             Job Title                     Job Location  \
# 0             Junior Insights Analyst                           Sydney
# 1  Graduate Data Analyst & Programmer                       Gold Coast
# 2                        Data Analyst  West Gippsland & Latrobe Valley
# 3                Data Analyst/Manager                           Sydney
# 4                        Data Analyst                              ACT
#
#                        Job Company                            Job Industry  \
# 0                 Oneflare Pty Ltd                                   Sales
# 1                 Tebbutt Research              Marketing & Communications
# 2      Hays Information Technology                    Government & Defence
# 3  Finite IT Recruitment Solutions  Information & Communication Technology
# 4        Hudson - Project Services  Information & Communication Technology
#
#                                        Search Engine
# 0                            Oneflare Pty Ltd Sydney
# 1                        Tebbutt Research Gold Coast
# 2  Hays Information Technology West Gippsland & L...
# 3             Finite IT Recruitment Solutions Sydney
# 4                      Hudson - Project Services ACT

# %% [markdown]
# The below code adds Lat and Lng columns to the dataframe to set up the dataframe further for the Google API

# %%
#adding latitude and longitude columns
Job_df2['Lat'] = ""
Job_df2['Lng']=""
# Out:
# /Users/dhanyamaheswaran/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/dhanyamaheswaran/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# The following code loops through all the search engine column and outputs a Lat and Lng from the Google Places API. Try and Except is used so that if there is an error, the code will not automatically stop.

# %%
for index, row in Job_df2.iterrows():
    
    search_string=row["Search Engine"]
    
    try:
        url = f'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={search_string}&inputtype=textquery&fields=photos,formatted_address,name,rating,opening_hours,geometry&key={gkey}'
        # Run request
        response = requests.get(url)
        search_geo = response.json()
        
    
        Job_df2.loc[index, 'Lat'] = search_geo["candidates"][0]['geometry']['location']['lat']
        Job_df2.loc[index, "Lng"]=search_geo["candidates"][0]['geometry']['location']['lng']

    
    #in the case of a JSONDecode Error, this ensures the code will keep running
    except (KeyError, IndexError, ValueError):
        Job_df2.loc[index, 'Lat'] = "No Coordinates"
        Job_df2.loc[index, 'Lng'] = "No Coordinates"
# Out:
# /Users/dhanyamaheswaran/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/dhanyamaheswaran/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/dhanyamaheswaran/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /Users/dhanyamaheswaran/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/dhanyamaheswaran/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Job_df2.head(15)
# Out:
#                              Job Title                     Job Location  \
# 0              Junior Insights Analyst                           Sydney
# 1   Graduate Data Analyst & Programmer                       Gold Coast
# 2                         Data Analyst  West Gippsland & Latrobe Valley
# 3                 Data Analyst/Manager                           Sydney
# 4                         Data Analyst                              ACT
# 5         Graduate Estate Data Analyst                        Melbourne
# 6                         Data Analyst                           Sydney
# 7       Customer Insights Data Analyst                         Brisbane
# 8       Master Data Analyst - Reynella                         Adelaide
# 9             Scientist (Data Analyst)  Southern Highlands & Tablelands
# 10            Scientist (Data Analyst)  Southern Highlands & Tablelands
# 11          Cloud Data Analyst (Azure)                        Melbourne
# 12                 Oracle Data Analyst                           Sydney
# 13                        Data Analyst                        Melbourne
# 14                        Data Analyst                        Melbourne
#
#                                          Job Company  \
# 0                                   Oneflare Pty Ltd
# 1                                   Tebbutt Research
# 2                        Hays Information Technology
# 3                    Finite IT Recruitment Solutions
# 4                          Hudson - Project Services
# 5                                             Ventia
# 6                               Teachers Mutual Bank
# 7                                eraDigital Services
# 8                           Accolade Wines Australia
# 9   Department of Planning, Industry and Environment
# 10  Department of Planning, Industry and Environment
# 11                                          Ambition
# 12                         Perigon Group Pty Limited
# 13        Department of Justice and Community Safety
# 14        Department of Justice and Community Safety
#
#                               Job Industry  \
# 0                                    Sales
# 1               Marketing & Communications
# 2                     Government & Defence
# 3   Information & Communication Technology
# 4   Information & Communication Technology
# 5                             Construction
# 6   Information & Communication Technology
# 7               Marketing & Communications
# 8   Information & Communication Technology
# 9                     Government & Defence
# 10                    Science & Technology
# 11  Information & Communication Technology
# 12  Information & Communication Technology
# 13                    Government & Defence
# 14  Information & Communication Technology
#
#                                         Search Engine             Lat  \
# 0                             Oneflare Pty Ltd Sydney        -33.8682
# 1                         Tebbutt Research Gold Coast        -27.9706
# 2   Hays Information Technology West Gippsland & L...        -38.1629
# 3              Finite IT Recruitment Solutions Sydney        -33.8667
# 4                       Hudson - Project Services ACT        -35.2759
# 5                                    Ventia Melbourne        -37.8575
# 6                         Teachers Mutual Bank Sydney        -33.8675
# 7                        eraDigital Services Brisbane  No Coordinates
# 8                   Accolade Wines Australia Adelaide        -35.0943
# 9   Department of Planning, Industry and Environme...        -34.4249
# 10  Department of Planning, Industry and Environme...        -34.4249
# 11                                 Ambition Melbourne        -37.8148
# 12                   Perigon Group Pty Limited Sydney        -33.8654
# 13  Department of Justice and Community Safety Mel...        -37.8127
# 14  Department of Justice and Community Safety Mel...        -37.8127
#
#                Lng
# 0          151.204
# 1          153.413
# 2          145.934
# 3          151.208
# 4          149.128
# 5          145.113
# 6          151.206
# 7   No Coordinates
# 8          138.543
# 9          150.899
# 10         150.899
# 11         144.963
# 12          151.21
# 13          144.97
# 14          144.97

# %% [markdown]
# In order to double check, the entries where lat and lng coordinates were not found were just displayed.

# %%
#check the ones that have no co-ordinates
Job_df2.loc[Job_df2['Lat'] == "No Coordinates"]
# Out:
#                                              Job Title  \
# 7                       Customer Insights Data Analyst
# 23                                        Data Analyst
# 26                             Data / Business Analyst
# 44                                 Senior Data Analyst
# 58                           APS 6 Policy/Data Analyst
# 109                        Experience Report Developer
# 116                                       Data Analyst
# 139                                       Data Analyst
# 150                                       Data Analyst
# 153                   Logistics and Operations Analyst
# 159                                       Data Analyst
# 174                        Online Map Quality Analysts
# 175                                       Data Manager
# 176                             Warehouse Data Analyst
# 178                                   Database Analyst
# 195                                   Data Analyst EL1
# 198         Expression of Interest - GIS opportunities
# 205                  Financial Accounting Data Analyst
# 209  Data and Integration Specialist - ETL - South ...
#
#                           Job Location                  Job Company  \
# 7                             Brisbane          eraDigital Services
# 23   West Gippsland and Latrobe Valley  Hays Information Technology
# 26                           Melbourne             GMAS Pty Limited
# 44                                 ACT                     Adaps IT
# 58                                 ACT  Hudson - Policy and Program
# 109                             Darwin               XIPNOS Pty Ltd
# 116       Newcastle, Maitland & Hunter      Karlka Recruiting Group
# 139                     Sunshine Coast                NOVA Partners
# 150                                ACT      First Grade Recruitment
# 153                          Melbourne           POPTECH Consulting
# 159                             Sydney             The Retail Score
# 174                             Sydney                   Lionbridge
# 175                           Brisbane           WW SURVEYS PTY LTD
# 176                          Melbourne     Caterpillar of Australia
# 178                             Sydney                Talent Street
# 195                                ACT             Silverstone Edge
# 198                                ACT                      Kinexus
# 205                           Brisbane           Private Advertiser
# 209                             Sydney  Data#3 People Solutions NSW
#
#                                Job Industry  \
# 7                Marketing & Communications
# 23                     Government & Defence
# 26   Information & Communication Technology
# 44   Information & Communication Technology
# 58                     Government & Defence
# 109  Information & Communication Technology
# 116                    Government & Defence
# 139  Information & Communication Technology
# 150  Information & Communication Technology
# 153    Manufacturing, Transport & Logistics
# 159  Information & Communication Technology
# 174  Information & Communication Technology
# 175                            Construction
# 176    Manufacturing, Transport & Logistics
# 178  Information & Communication Technology
# 195                    Government & Defence
# 198  Information & Communication Technology
# 205                              Accounting
# 209  Information & Communication Technology
#
#                                          Search Engine             Lat  \
# 7                         eraDigital Services Brisbane  No Coordinates
# 23   Hays Information Technology West Gippsland and...  No Coordinates
# 26                          GMAS Pty Limited Melbourne  No Coordinates
# 44                                        Adaps IT ACT  No Coordinates
# 58                     Hudson - Policy and Program ACT  No Coordinates
# 109                              XIPNOS Pty Ltd Darwin  No Coordinates
# 116  Karlka Recruiting Group Newcastle, Maitland & ...  No Coordinates
# 139                       NOVA Partners Sunshine Coast  No Coordinates
# 150                        First Grade Recruitment ACT  No Coordinates
# 153                       POPTECH Consulting Melbourne  No Coordinates
# 159                            The Retail Score Sydney  No Coordinates
# 174                                  Lionbridge Sydney  No Coordinates
# 175                        WW SURVEYS PTY LTD Brisbane  No Coordinates
# 176                 Caterpillar of Australia Melbourne  No Coordinates
# 178                               Talent Street Sydney  No Coordinates
# 195                               Silverstone Edge ACT  No Coordinates
# 198                                        Kinexus ACT  No Coordinates
# 205                        Private Advertiser Brisbane  No Coordinates
# 209                 Data#3 People Solutions NSW Sydney  No Coordinates
#
#                 Lng
# 7    No Coordinates
# 23   No Coordinates
# 26   No Coordinates
# 44   No Coordinates
# 58   No Coordinates
# 109  No Coordinates
# 116  No Coordinates
# 139  No Coordinates
# 150  No Coordinates
# 153  No Coordinates
# 159  No Coordinates
# 174  No Coordinates
# 175  No Coordinates
# 176  No Coordinates
# 178  No Coordinates
# 195  No Coordinates
# 198  No Coordinates
# 205  No Coordinates
# 209  No Coordinates

# %% [markdown]
# In order to data-clean, all Jobs where no coordinates were found was then deleted from the dataframe and it was exported as a csv

# %%
#Then delete the ones with no co-ordinates
final_Job_df=Job_df2.loc[Job_df2['Lat'] != "No Coordinates"]

# %%
#Finally export it to a csv
final_Job_df.to_csv("data/Final_job_df.csv")

# %%
df2=pd.read_csv("data/Final_job_df.csv")

# %%
#looking at al lthe unique values and mapping them to a state 
df2["Job Location"].unique()
# Out:
# array(['Sydney', 'Gold Coast', 'West Gippsland & Latrobe Valley', 'ACT',
#        'Melbourne', 'Adelaide', 'Southern Highlands & Tablelands',
#        'Perth', 'Northern QLD', 'Brisbane', 'South West Coast VIC',
#        'Bunbury & South West', 'Newcastle, Maitland & Hunter',
#        'Wollongong, Illawarra & South Coast', 'Hobart',
#        'Cairns & Far North', 'Launceston & North East',
#        'Ballarat & Central Highlands', 'Blue Mountains & Central West'],
#       dtype=object)

# %%
#replacing with states for the location values 
# create ChainMap
L1 = ['Adelaide']
d1 = dict.fromkeys(L1, 'SA')

L2 = ['Gold Coast', "Brisbane", 'Northern QLD', 'Cairns & Far North']
d2 = dict.fromkeys(L2, 'QLD')

L3 = ['Sydney', "Southern Highlands & Tablelands", 'Newcastle, Maitland & Hunter', 'Wollongong, Illawarra & South Coast', 'Blue Mountains & Central West']
d3 = dict.fromkeys(L3, 'NSW')

L4 = ['Melbourne', "South West Coast VIC"]
d4 = dict.fromkeys(L4, 'VIC')

L5 = ['Bunbury & South West', "Perth"]
d5 = dict.fromkeys(L5, 'WA')

L6 = ['Hobart', "Launceston & North East"]
d6 = dict.fromkeys(L6, 'TAS')

L7 = ['Alice Springs & Central Australia']
d7 = dict.fromkeys(L7, 'NT')

L8 = ['ACT']
d8 = dict.fromkeys(L8, 'ACT')


d = {**d1, **d2, **d3, **d4, **d5, **d6, **d7, **d8}
print (d)
# Out:
# {'Adelaide': 'SA', 'Gold Coast': 'QLD', 'Brisbane': 'QLD', 'Northern QLD': 'QLD', 'Cairns & Far North': 'QLD', 'Sydney': 'NSW', 'Southern Highlands & Tablelands': 'NSW', 'Newcastle, Maitland & Hunter': 'NSW', 'Wollongong, Illawarra & South Coast': 'NSW', 'Blue Mountains & Central West': 'NSW', 'Melbourne': 'VIC', 'South West Coast VIC': 'VIC', 'Bunbury & South West': 'WA', 'Perth': 'WA', 'Hobart': 'TAS', 'Launceston & North East': 'TAS', 'Alice Springs & Central Australia': 'NT', 'ACT': 'ACT'}

# %%
df2['State'] = df2['Job Location'].map(d)

# %%
df2.head(15)
# Out:
#     Unnamed: 0                           Job Title  \
# 0            0             Junior Insights Analyst
# 1            1  Graduate Data Analyst & Programmer
# 2            2                        Data Analyst
# 3            3                Data Analyst/Manager
# 4            4                        Data Analyst
# 5            5        Graduate Estate Data Analyst
# 6            6                        Data Analyst
# 7            8      Master Data Analyst - Reynella
# 8            9            Scientist (Data Analyst)
# 9           10            Scientist (Data Analyst)
# 10          11          Cloud Data Analyst (Azure)
# 11          12                 Oracle Data Analyst
# 12          13                        Data Analyst
# 13          14                        Data Analyst
# 14          16                    EL1 Data Analyst
#
#                        Job Location  \
# 0                            Sydney
# 1                        Gold Coast
# 2   West Gippsland & Latrobe Valley
# 3                            Sydney
# 4                               ACT
# 5                         Melbourne
# 6                            Sydney
# 7                          Adelaide
# 8   Southern Highlands & Tablelands
# 9   Southern Highlands & Tablelands
# 10                        Melbourne
# 11                           Sydney
# 12                        Melbourne
# 13                        Melbourne
# 14                              ACT
#
#                                          Job Company  \
# 0                                   Oneflare Pty Ltd
# 1                                   Tebbutt Research
# 2                        Hays Information Technology
# 3                    Finite IT Recruitment Solutions
# 4                          Hudson - Project Services
# 5                                             Ventia
# 6                               Teachers Mutual Bank
# 7                           Accolade Wines Australia
# 8   Department of Planning, Industry and Environment
# 9   Department of Planning, Industry and Environment
# 10                                          Ambition
# 11                         Perigon Group Pty Limited
# 12        Department of Justice and Community Safety
# 13        Department of Justice and Community Safety
# 14                                   SOS Recruitment
#
#                               Job Industry  \
# 0                                    Sales
# 1               Marketing & Communications
# 2                     Government & Defence
# 3   Information & Communication Technology
# 4   Information & Communication Technology
# 5                             Construction
# 6   Information & Communication Technology
# 7   Information & Communication Technology
# 8                     Government & Defence
# 9                     Science & Technology
# 10  Information & Communication Technology
# 11  Information & Communication Technology
# 12                    Government & Defence
# 13  Information & Communication Technology
# 14                    Government & Defence
#
#                                         Search Engine        Lat         Lng  \
# 0                             Oneflare Pty Ltd Sydney -33.868220  151.203777
# 1                         Tebbutt Research Gold Coast -27.970591  153.413115
# 2   Hays Information Technology West Gippsland & L... -38.162890  145.933707
# 3              Finite IT Recruitment Solutions Sydney -33.866704  151.208325
# 4                       Hudson - Project Services ACT -35.275898  149.127980
# 5                                    Ventia Melbourne -37.857500  145.113248
# 6                         Teachers Mutual Bank Sydney -33.867538  151.205714
# 7                   Accolade Wines Australia Adelaide -35.094292  138.543356
# 8   Department of Planning, Industry and Environme... -34.424912  150.898812
# 9   Department of Planning, Industry and Environme... -34.424912  150.898812
# 10                                 Ambition Melbourne -37.814813  144.962949
# 11                   Perigon Group Pty Limited Sydney -33.865414  151.210016
# 12  Department of Justice and Community Safety Mel... -37.812732  144.970403
# 13  Department of Justice and Community Safety Mel... -37.812732  144.970403
# 14                                SOS Recruitment ACT -35.337949  149.180661
#
#    State
# 0    NSW
# 1    QLD
# 2    NaN
# 3    NSW
# 4    ACT
# 5    VIC
# 6    NSW
# 7     SA
# 8    NSW
# 9    NSW
# 10   VIC
# 11   NSW
# 12   VIC
# 13   VIC
# 14   ACT

# %%
#count by location the gauge chart 
#Location in NSW
#by sub-category for each state

# %%
df2=df2.rename(columns={"Job Industry": "Industry"})

df2["Industry"].unique()
# Out:
# array(['Sales', 'Marketing & Communications', 'Government & Defence',
#        'Information & Communication Technology', 'Construction',
#        'Science & Technology', 'Banking & Financial Services',
#        'Insurance & Superannuation', 'Healthcare & Medical',
#        'Administration & Office Support', 'Accounting',
#        'Education & Training', 'Consulting & Strategy',
#        'Human Resources & Recruitment', 'Real Estate & Property',
#        'Hospitality & Tourism', 'Manufacturing, Transport & Logistics',
#        'Community Services & Development', 'Engineering',
#        'Mining, Resources & Energy'], dtype=object)

# %%
Industry2=df2.Industry.map({'Sales' : "Sales", 'Marketing & Communications': 'Marketing', 'Information & Communication Technology' : "ICT",
                 'Government & Defence' : "Govt", 'Banking & Financial Services': "Banking",'Science & Technology': "Science",'Consulting & Strategy' : "Consulting", 
                  "Insurance & Superannuation" : "Insurance", "Administration & Office Support" : "Admin", "Accounting": "Accounting", 
                 "Healthcare & Medical":"Healthcare", "Education & Training" : "Educ", "Human Resources & Recruitment": "HR", "Real Estate & Property": "Real Estate", "Manufacturing, Transport & Logistics":"Transport", "Hospitality & Tourism": "Hospitality", 
                 "Community Services & Development":"Community", "Engineering":"Engineering", "Mining, Resources & Energy":"Mining" })

# %%
df2['Job Industry 2'] = Industry2

grouped_state = df2.groupby('State')
grouped_state_1=grouped_state["Job Title"].count()

grouped_state_1
list1=[]

# %%
#dropping all NA values
df2=df2.dropna()

# %%
grouped_count_state=pd.DataFrame(grouped_state_1)
grouped_state_1=grouped_state_1.to_dict()
list1.append(grouped_state_1)

# %%
print(list1)
# Out:
# [{'ACT': 34, 'NSW': 77, 'QLD': 18, 'SA': 8, 'TAS': 4, 'VIC': 37, 'WA': 9}]

# %%
grouped_state_2 = df2.groupby(['State','Job Industry 2'])

# %%
grouped_state_industry=grouped_state_2["Job Title"].count()

# %%
grouped_state_industry=pd.DataFrame(grouped_state_industry)

# %%
from collections import defaultdict
results = defaultdict(lambda: defaultdict(dict))

for index, value in grouped_state_industry.itertuples():
    for i, key in enumerate(index):
        if i == 0:
            nested = results[key]
        elif i == len(index) - 1:
            nested[key] = value
        else:
            nested = nested[key]

# %%
list1.append(results)

# %%
grouped_state_3 = df2.groupby(['State','Job Location'])
grouped_state_location=grouped_state_3["Job Title"].count()
grouped_state_location=pd.DataFrame(grouped_state_location)

# %%
from collections import defaultdict
results2 = defaultdict(lambda: defaultdict(dict))

for index, value in grouped_state_location.itertuples():
    for i, key in enumerate(index):
        if i == 0:
            nested = results2[key]
        elif i == len(index) - 1:
            nested[key] = value
        else:
            nested = nested[key]

# %%
list1.append(results2)

# %%
with open('data/job_data.json', 'w') as fp:
    json.dump(list1, fp)
